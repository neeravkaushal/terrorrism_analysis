# %%
import pandas as pd, numpy as np, time, matplotlib.pyplot as plt
df = pd.read_excel('/home/neerav/Downloads/globalterrorismdb_0919dist.xlsx')

# %%
pd.options.display.max_rows = 40000
pd.options.display.max_columns = 400
import seaborn as sns
sns.set(style="darkgrid")

# %%
print(sorted(list(df.columns)))
# Out:
# ['INT_ANY', 'INT_IDEO', 'INT_LOG', 'INT_MISC', 'addnotes', 'alternative', 'alternative_txt', 'approxdate', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'city', 'claim2', 'claim3', 'claimed', 'claimmode', 'claimmode2', 'claimmode2_txt', 'claimmode3', 'claimmode3_txt', 'claimmode_txt', 'compclaim', 'corp1', 'corp2', 'corp3', 'country', 'country_txt', 'crit1', 'crit2', 'crit3', 'dbsource', 'divert', 'doubtterr', 'eventid', 'extended', 'gname', 'gname2', 'gname3', 'gsubname', 'gsubname2', 'gsubname3', 'guncertain1', 'guncertain2', 'guncertain3', 'hostkidoutcome', 'hostkidoutcome_txt', 'iday', 'imonth', 'individual', 'ishostkid', 'iyear', 'kidhijcountry', 'latitude', 'location', 'longitude', 'motive', 'multiple', 'natlty1', 'natlty1_txt', 'natlty2', 'natlty2_txt', 'natlty3', 'natlty3_txt', 'ndays', 'nhostkid', 'nhostkidus', 'nhours', 'nkill', 'nkillter', 'nkillus', 'nperpcap', 'nperps', 'nreleased', 'nwound', 'nwoundte', 'nwoundus',
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.914640e+05  191464.000000  191464.000000  191464.000000
# mean   2.003486e+11    2003.420136       6.462510      15.507688
# std    1.334949e+09      13.349405       3.388515       8.807727
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991083e+11    1991.000000       4.000000       8.000000
# 50%    2.010031e+11    2010.000000       6.000000      15.000000
# 75%    2.015013e+11    2015.000000       9.000000      23.000000
# max    2.018123e+11    2018.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  191464.000000  191464.000000  191464.000000  186884.000000
# mean        0.047476     131.290446       7.205167      23.462121
# std         0.212656     112.058063       2.923811      18.405309
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.head(5)

# %%
to_drop = ['approxdate','resolution','region_txt']

# %%
df[['city','provstate','summary']][ pd.notna(df['country']) ] # FInd elements where ollowing key is not nan
# Out:
#                              city         provstate  \
# 0                   Santo Domingo          National
# 1                     Mexico city           Federal
# 2                         Unknown            Tarlac
# 3                          Athens            Attica
# 4                         Fukouka           Fukouka
# ...                           ...               ...
# 191459                Sorkhi Sang             Zabul
# 191460  Khwaja Sabz Posh district            Faryab
# 191461                    Dik Sar           Jawzjan
# 191462           Nad Ali district           Helmand
# 191463                    Belfast  Northern Ireland
#
#                                                   summary
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# ...

# %%
#df[['eventid','iyear','imonth','iday','approxdate']][ pd.notna(df['approxdate']) ] # FInd elements where ollowing key is not nan

# %%
#%matplotlib
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
plt.figure(figsize=(20,15))
ax = plt.axes(projection=ccrs.PlateCarree())
plt.scatter(df['longitude'], df['latitude'], s=1, c='r')
plt.savefig("abc.png",dpi=400)
ax.stock_img()

# %%
plt.figure(figsize=(10,10))
sns.relplot(x="latitude", y="longitude", data=df);
plt.savefig('def.png', dpi=600)

# %%
sns.jointplot(x='imonth', y='country', data=df)

# %%
sns.relplot(x="imonth", y="country", kind="line", ci="sd", data=df);

# %%
df['country'].unique()
# Out:
# array([  58,  130,  160,   78,  101,  217,  218,   98,  499,   65,   83,
#         222,  362,  199,  102,  185,   30,   60,   11,  110,   96,  209,
#         158,   94,  603,   45,   26,  145,  142,   21,   38,   14,  153,
#         230,  198,   49,  406,   36,   97,  161,  201,  156,  106,  155,
#          15,  236,   92,   69,  428,   31,  604,  605,  162,    6,   61,
#         205,   87,  195,  136,   53,  138,    4,  159,   43,   88,  235,
#          59,  144,  121,  178,   29,  100,   42,  377,    7,  200,  184,
#         215,  183,  104,   95,  182,  203,  186,  139,   17,  147,   20,
#         207,   19,    8,  128,  173,   56,   93,  124,  403,  359,   55,
#         349,   86,  137,  208,  213,  151,  111,   72,  113,   18,   89,
#         174,  231,   84,   80,  532,   22,   81,  127,  221,    5,   41,
#         176,   57,  164,   32,  196,  197,  116,   91,   70,   66,   33,
#         143,  166,  146,  141,  204,   68,   67,   76,  122,  129,   90,
# ...

# %%
# %matplotlib inline
plt.figure(figsize=(10,10))
g = df.groupby('country').size()
plt.scatter(g.index, g, alpha=0.7, s=50)
plt.ylim(-100,5000)
plt.xlim(0,250)
# Out:
# (0, 250)
